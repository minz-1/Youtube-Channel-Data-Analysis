# %%
API_KEY = 'AIzaSyByIqPh7P7fYvnFMogO0zzx3-f8wPOzxfY'
CHANNEL_ID = 'UCAuUUnT6oDeKwE6v1NGQxug'
playlist_id='UUAuUUnT6oDeKwE6v1NGQxug'

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
youtube = build('youtube', 'v3', developerKey=API_KEY)
def get_channel_stats(youtube,CHANNEL_ID):
    request=youtube.channels().list(
        part='snippet,contentDetails',
        id=CHANNEL_ID)
    response=request.execute()
    data= response['items'][0]['snippet']['title']
    return data

# %%
get_channel_stats(youtube,CHANNEL_ID)
# Out:
# 'TED'

# %% [markdown]
# #getting video ids

# %%
def get_video_ids(youtube,playlist_id):
    request=youtube.playlistItems().list(
        part="contentDetails",
        playlistId=playlist_id,
        maxResults=50)
    video_ids=[]
    response=request.execute()
    for i in range(len(response['items'])):
                   data=response['items'][i]['contentDetails']['videoId']
                   video_ids.append(data)
    next_page_token=response.get('nextPageToken')
    more_pages=True

    while more_pages:
        if next_page_token is None:
            more_pages=False
        else:
            request=youtube.playlistItems().list(
                  part="contentDetails",
                  playlistId=playlist_id,
                  maxResults=50,
                  pageToken=next_page_token)
            response=request.execute()
            for i in range(len(response['items'])):
                   data=response['items'][i]['contentDetails']['videoId']
                   video_ids.append(data)
            next_page_token=response.get('nextPageToken')
    return video_ids

# %%
video_ids=get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['zWfkFEHe9QY',
#  'ooMXEwl7N8Y',
#  'GjtqcYOtxhA',
#  'hqpKUkYqreM',
#  'QXGTNROtJkY',
#  'shgYbdOVgpY',
#  'tpAG2eZZGxo',
#  'gElClXpg4J0',
#  '_D8YJ6opZYU',
#  'bxbQkaIB8PA',
#  'Jc97OeIpaEY',
#  '4fOWQfzWHbc',
#  'sexqiDz8fWs',
#  'p3uBMqCPSDk',
#  '6mck0ycBYAo',
#  '5MWT_doo68k',
#  'C8Iwvgj7Xwk',
#  'TZOoT8AbkNE',
#  '1WXh_9S3q2c',
#  'PsFlp3u74mI',
#  'OgK5eQQIUGQ',
#  't8qtf2lc8FU',
#  '-k-bg0q3NNw',
#  '81_20RfdX3c',
#  'r4n79ZRepi8',
#  '-074mbRqFrA',
#  'C4QMPhiF_as',
#  'n8QoLnT4ygo',
#  'oJ0Nec57-08',
#  'eMiPKpXbm9A',
#  'ADAmTm_45uk',
#  'adza_PZiBNA',
#  'K_RSZC0s8a4',
#  'BIbAyapnfOI',
#  'utTlli1Ett0',
#  'G1DmWN4EH5M',
#  'q3_AS6GM2Cs',
#  'gdEeSfi1ywI',
#  '4lxyPcI7kn0',
#  '7CL8OgCs80I',
#  'VjegFh1zhY4',
#  'lZTBIO3OtYc',
#  'otNea-jNmXU',
#  'bRyFB4mQHzY',
#  'hO_v--mXE4M',
#  'LsojAy3i1gE',
#  'yvf6xqSkAcY',
#  'p0Nag5w42ys',
#  'jc0tTOhRVe0',
#  'FN6JIyntwR0',
#  'uxQ0OoyaALQ',
#  'U9d0p96N1iw',
#  'lrUQn26zp_c',
#  'DHL6_DebL1Q',
#  'OTIx-2udf6Y',
# ...

# %%
def get_video_deets(youtube, video_ids):
    all_vids_info = []
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,statistics,contentDetails',
            id=','.join(video_ids[i:i + 50])
        )
        response = request.execute()
        
        for video in response['items']:
                
                vid_info = dict(
                Title=video['snippet']['title'],
                Publish_date=video['snippet']['publishedAt'],
                Description=video['snippet']['description'],
                Duration=video['contentDetails']['duration'],
                Views=int(video['statistics'].get('viewCount', 0)),
                Likes=int(video['statistics'].get('likeCount', 0)),
                Comments=int(video['statistics'].get('commentCount', 0))
                )
                all_vids_info.append(vid_info)

    return all_vids_info

# %%
video_details=get_video_deets(youtube,video_ids)
video_details
# Out:
# [{'Title': "“When you feel powerless, it's often actually because you are powerful.” #TEDTalks",
#   'Publish_date': '2025-04-25T20:00:41Z',
#   'Description': '"If you can\'t respect the basic fundamental underlying principles with which we order society — which is \'Do not steal\' — then what are you left with?" asks investigative journalist Carole Cadwalladr. \nWatch the full video here: https://youtu.be/hqpKUkYqreM',
#   'Duration': 'PT1M9S',
#   'Views': 12828,
#   'Likes': 620,
#   'Comments': 21},
#  {'Title': 'The AI Arsenal That Could Stop World War III | Palmer Luckey | TED',
#   'Publish_date': '2025-04-25T15:01:30Z',
# ...

# %%
video_data=pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                   Title          Publish_date  \
# 0     “When you feel powerless, it's often actually ...  2025-04-25T20:00:41Z
# 1     The AI Arsenal That Could Stop World War III |...  2025-04-25T15:01:30Z
# 2      To talk climate, lead with fun. #TEDTalks #Vegan  2025-04-23T17:00:19Z
# 3     Can Big Tech and Privacy Coexist? | Carole Cad...  2025-04-23T16:02:25Z
# 4     Your Inner Fire Is Your Greatest Strength | Xi...  2025-04-22T17:01:28Z
# ...                                                 ...                   ...
# 5068  Do schools kill creativity? | Sir Ken Robinson...  2007-01-07T05:00:34Z
# 5069           Majora Carter: Greening the ghetto | TED  2007-01-07T04:18:33Z
# 5070               Dean Ornish: The world's killer diet  2007-01-06T23:47:40Z
# 5071  Secrets of success in 8 words, 3 minutes | Ric...  2007-01-06T19:53:49Z
# 5072               If I controlled the Internet | Rives  2006-12-25T17:58:08Z
#
# ...

# %%
video_data.to_csv('youtube.csv',index=False)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
import csv


driver_path = '/Users/mac/Desktop/chromedriver'  

options = Options()
options.add_argument('--headless') 
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--log-level=3') 

service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=options)


url = "https://www.youtube.com/@TED/videos"
driver.get(url)
time.sleep(5)


SCROLLS = 50 

for _ in range(SCROLLS):
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(3)


videos = driver.find_elements(By.TAG_NAME, 'ytd-rich-grid-media')


with open('ted_videos.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Title', 'Link', 'Views', 'Upload Date', 'Duration']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for video in videos:
        try:
            anchor = video.find_element(By.CSS_SELECTOR, 'a#video-title-link')
            title = anchor.get_attribute('title')
            link = anchor.get_attribute('href')
            if not link.startswith("http"):
                link = f"https://www.youtube.com{link}"

           
            metadata_spans = video.find_elements(By.XPATH, './/span[@class="inline-metadata-item style-scope ytd-video-meta-block"]')
            views = metadata_spans[0].text if len(metadata_spans) > 0 else "N/A"
            upload_date = metadata_spans[1].text if len(metadata_spans) > 1 else "N/A"

        
            try:
                duration = video.find_element(By.CLASS_NAME, 'ytd-thumbnail-overlay-time-status-renderer').text.strip()
            except:
                duration = "N/A"

            writer.writerow({
                'Title': title,
                'Link': link,
                'Views': views,
                'Upload Date': upload_date,
                'Duration': duration
            })

            print(f"✅ Scraped: {title} | Views: {views} | Date: {upload_date} | Duration: {duration}")
        
        except Exception as e:
            print(f"⚠️ Skipped one due to error: {e}")


driver.quit()
print("🎉 Done! Data saved in ted_videos.csv")
# Out:
# ✅ Scraped: The Next Computer? Your Glasses | Shahram Izadi | TED | Views: 86K views | Date: 22 hours ago | Duration:
# ✅ Scraped: The Key to Navigating Change With Confidence | Kristy Ellmer | TED | Views: 27K views | Date: 2 days ago | Duration:
# ✅ Scraped: Why Are We Sending Critical Metals to the Dump? | Jeff More | TED | Views: 19K views | Date: 4 days ago | Duration:
# ✅ Scraped: Meet NEO, Your Robot Butler in Training | Bernt Børnich | TED | Views: 377K views | Date: 5 days ago | Duration:
# ✅ Scraped: This Is What a Digital Coup Looks Like | Carole Cadwalladr | TED | Views: 943K views | Date: 9 days ago | Duration:
# ✅ Scraped: Is Generosity the Most Underrated Leadership Skill? | Joe Davis | TED | Views: 27K views | Date: 10 days ago | Duration:
# ✅ Scraped: An Ethicist’s Guide to Living a Good Life | Ira Bedzow | TED | Views: 34K views | Date: 11 days ago | Duration:
# ...

# %%
import isodate
from googleapiclient.discovery import build

# Your API Key and Channel ID (TED's Channel ID)

CHANNEL_ID = 'UCAuUUnT6oDeKwE6v1NGQxug'  # TED Channel ID
API_KEY = 'AIzaSyByIqPh7P7fYvnFMogO0zzx3-f8wPOzxfY'
# Initialize the YouTube API client
youtube = build('youtube', 'v3', developerKey=API_KEY)

# Request to get the latest videos of TED channel
request = youtube.search().list(
    part="snippet",
    channelId=CHANNEL_ID,
    maxResults=5,  # Modify as needed
    order="date",  # Sort by upload date
    type="video"   # Ensure we get only video results
)

response = request.execute()

# Process the response to extract video details
for item in response['items']:
    if item['id']['kind'] == 'youtube#video':
        video_id = item['id']['videoId']
        video_url = f'https://www.youtube.com/watch?v={video_id}'
        video_title = item['snippet']['title']

        # Get video duration using 'contentDetails' part
        video_details = youtube.videos().list(part="contentDetails", id=video_id).execute()
        duration = video_details['items'][0]['contentDetails']['duration']

        # Convert ISO 8601 duration to seconds
        duration_seconds = isodate.parse_duration(duration).total_seconds()

        # Filter for videos longer than 5 minutes (300 seconds)
        if duration_seconds > 300:
            print(f'✅ Scraped: {video_title} - {video_url} | Duration: {duration_seconds} seconds')
# Out:
# ✅ Scraped: The Next Computer? Your Glasses | Shahram Izadi | TED - https://www.youtube.com/watch?v=gElClXpg4J0 | Duration: 967.0 seconds
# ✅ Scraped: The Key to Navigating Change With Confidence | Kristy Ellmer | TED - https://www.youtube.com/watch?v=Jc97OeIpaEY | Duration: 768.0 seconds
# ✅ Scraped: Meet NEO, Your Robot Butler in Training | Bernt Børnich | TED - https://www.youtube.com/watch?v=p3uBMqCPSDk | Duration: 889.0 seconds
